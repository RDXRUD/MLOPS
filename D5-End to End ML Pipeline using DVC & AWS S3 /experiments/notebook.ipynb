# %% [markdown]
# ## Basic Imports

# %%
# Importing necessary libraries
import numpy as np        # For numerical operations
import pandas as pd       # For data manipulation and analysis
import matplotlib.pyplot as plt  # For data visualization
# %matplotlib inline

# Importing WordCloud for text visualization
from wordcloud import WordCloud

# Importing NLTK for natural language processing
import nltk
from nltk.corpus import stopwords    # For stopwords


# Downloading NLTK data
nltk.data.path.append('/Users/rudrakshagarwal/nltk_data') 
nltk.download('stopwords')   # Downloading stopwords data
nltk.download('punkt_tab')       # Downloading tokenizer data
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rudrakshagarwal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/rudrakshagarwal/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Read the CSV file
df = pd.read_csv('spam.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(columns = ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace = True)
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Rename the columns name
df.rename(columns = {'v1': 'target', 'v2': 'text'}, inplace = True)
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['target'] = encoder.fit_transform(df['target'])

df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
#check duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
len(df)
# Out:
# 5572

# %%
#remove Duplicate
df = df.drop_duplicates(keep = 'first')
len(df)
# Out:
# 5169

# %% [markdown]
# ## Feature Engg

# %%
# Importing the Porter Stemmer for text stemming
from nltk.stem.porter import PorterStemmer

# Importing the string module for handling special characters
import string

# Creating an instance of the Porter Stemmer
ps = PorterStemmer()

# %%
# Lowercase transformation and text preprocessing function
def transform_text(text):
    # Transform the text to lowercase
    text = text.lower()
    
    # Tokenization using NLTK
    text = nltk.word_tokenize(text)
    print(text)
    # Removing special characters
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    print(y)        
    # Removing stop words and punctuation
    text = y[:]
    y.clear()
    
    # Loop through the tokens and remove stopwords and punctuation
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    print(y)
    # Stemming using Porter Stemmer
    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    
    # Join the processed tokens back into a single string
    return " ".join(y)

# %%
transform_text("Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...")
# Out:
# ['go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'cine', 'there', 'got', 'amore', 'wat', '...']
# ['go', 'until', 'jurong', 'point', 'crazy', 'available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'there', 'got', 'amore', 'wat']
# ['go', 'jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'got', 'amore', 'wat']
# 'go jurong point crazi avail bugi n great world la e buffet cine got amor wat'

# %%
df['transformed_text'] = df['text'].apply(transform_text)
df.head()
# Out:
# ['go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'cine', 'there', 'got', 'amore', 'wat', '...']
# ['go', 'until', 'jurong', 'point', 'crazy', 'available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'there', 'got', 'amore', 'wat']
# ['go', 'jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'got', 'amore', 'wat']
# ['ok', 'lar', '...', 'joking', 'wif', 'u', 'oni', '...']
# ['ok', 'lar', 'joking', 'wif', 'u', 'oni']
# ['ok', 'lar', 'joking', 'wif', 'u', 'oni']
# ['free', 'entry', 'in', '2', 'a', 'wkly', 'comp', 'to', 'win', 'fa', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', 'fa', 'to', '87121', 'to', 'receive', 'entry', 'question', '(', 'std', 'txt', 'rate', ')', 't', '&', 'c', "'s", 'apply', '08452810075over18', "'s"]
# ['free', 'entry', 'in', '2', 'a', 'wkly', 'comp', 'to', 'win', 'fa', 'cup', 'final', 'tkts', '21st', 'may', 'text', 'fa', 'to', '87121', 'to', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 't', 'c', 'apply', '08452810075over18']
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', 'may', 'text', 'fa', '87121', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'c', 'apply', '08452810075over18']
# ['u', 'dun', 'say', 'so', 'early', 'hor', '...', 'u', 'c', 'already', 'then', 'say', '...']
# ['u', 'dun', 'say', 'so', 'early', 'hor', 'u', 'c', 'already', 'then', 'say']
# ['u', 'dun', 'say', 'early', 'hor', 'u', 'c', 'already', 'say']
# ['nah', 'i', 'do', "n't", 'think', 'he', 'goes', 'to', 'usf', ',', 'he', 'lives', 'around', 'here', 'though']
# ['nah', 'i', 'do', 'think', 'he', 'goes', 'to', 'usf', 'he', 'lives', 'around', 'here', 'though']
# ['nah', 'think', 'goes', 'usf', 'lives', 'around', 'though']
# ['freemsg', 'hey', 'there', 'darling', 'it', "'s", 'been', '3', 'week', "'s", 'now', 'and', 'no', 'word', 'back', '!', 'i', "'d", 'like', 'some', 'fun', 'you', 'up', 'for', 'it', 'still', '?', 'tb', 'ok', '!', 'xxx', 'std', 'chgs', 'to', 'send', ',', 'å£1.50', 'to', 'rcv']
# ['freemsg', 'hey', 'there', 'darling', 'it', 'been', '3', 'week', 'now', 'and', 'no', 'word', 'back', 'i', 'like', 'some', 'fun', 'you', 'up', 'for', 'it', 'still', 'tb', 'ok', 'xxx', 'std', 'chgs', 'to', 'send', 'to', 'rcv']
# ['freemsg', 'hey', 'darling', '3', 'week', 'word', 'back', 'like', 'fun', 'still', 'tb', 'ok', 'xxx', 'std', 'chgs', 'send', 'rcv']
# ['even', 'my', 'brother', 'is', 'not', 'like', 'to', 'speak', 'with', 'me', '.', 'they', 'treat', 'me', 'like', 'aids', 'patent', '.']
# ['even', 'my', 'brother', 'is', 'not', 'like', 'to', 'speak', 'with', 'me', 'they', 'treat', 'me', 'like', 'aids', 'patent']
# ['even', 'brother', 'like', 'speak', 'treat', 'like', 'aids', 'patent']
# ['as', 'per', 'your', 'request', "'melle", 'melle', '(', 'oru', 'minnaminunginte', 'nurungu', 'vettam', ')', "'", 'has', 'been', 'set', 'as', 'your', 'callertune', 'for', 'all', 'callers', '.', 'press', '*', '9', 'to', 'copy', 'your', 'friends', 'callertune']
# ['as', 'per', 'your', 'request', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'has', 'been', 'set', 'as', 'your', 'callertune', 'for', 'all', 'callers', 'press', '9', 'to', 'copy', 'your', 'friends', 'callertune']
# ['per', 'request', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'callers', 'press', '9', 'copy', 'friends', 'callertune']
# ['winner', '!', '!', 'as', 'a', 'valued', 'network', 'customer', 'you', 'have', 'been', 'selected', 'to', 'receivea', 'å£900', 'prize', 'reward', '!', 'to', 'claim', 'call', '09061701461.', 'claim', 'code', 'kl341', '.', 'valid', '12', 'hours', 'only', '.']
# ['winner', 'as', 'a', 'valued', 'network', 'customer', 'you', 'have', 'been', 'selected', 'to', 'receivea', 'prize', 'reward', 'to', 'claim', 'call', 'claim', 'code', 'kl341', 'valid', '12', 'hours', 'only']
# ['winner', 'valued', 'network', 'customer', 'selected', 'receivea', 'prize', 'reward', 'claim', 'call', 'claim', 'code', 'kl341', 'valid', '12', 'hours']
# ['had', 'your', 'mobile', '11', 'months', 'or', 'more', '?', 'u', 'r', 'entitled', 'to', 'update', 'to', 'the', 'latest', 'colour', 'mobiles', 'with', 'camera', 'for', 'free', '!', 'call', 'the', 'mobile', 'update', 'co', 'free', 'on', '08002986030']
# ['had', 'your', 'mobile', '11', 'months', 'or', 'more', 'u', 'r', 'entitled', 'to', 'update', 'to', 'the', 'latest', 'colour', 'mobiles', 'with', 'camera', 'for', 'free', 'call', 'the', 'mobile', 'update', 'co', 'free', 'on', '08002986030']
# ['mobile', '11', 'months', 'u', 'r', 'entitled', 'update', 'latest', 'colour', 'mobiles', 'camera', 'free', 'call', 'mobile', 'update', 'co', 'free', '08002986030']
# ['i', "'m", 'gon', 'na', 'be', 'home', 'soon', 'and', 'i', 'do', "n't", 'want', 'to', 'talk', 'about', 'this', 'stuff', 'anymore', 'tonight', ',', 'k', '?', 'i', "'ve", 'cried', 'enough', 'today', '.']
# ['i', 'gon', 'na', 'be', 'home', 'soon', 'and', 'i', 'do', 'want', 'to', 'talk', 'about', 'this', 'stuff', 'anymore', 'tonight', 'k', 'i', 'cried', 'enough', 'today']
# ['gon', 'na', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight', 'k', 'cried', 'enough', 'today']
# ['six', 'chances', 'to', 'win', 'cash', '!', 'from', '100', 'to', '20,000', 'pounds', 'txt', '>', 'csh11', 'and', 'send', 'to', '87575.', 'cost', '150p/day', ',', '6days', ',', '16+', 'tsandcs', 'apply', 'reply', 'hl', '4', 'info']
# ['six', 'chances', 'to', 'win', 'cash', 'from', '100', 'to', 'pounds', 'txt', 'csh11', 'and', 'send', 'to', 'cost', '6days', 'tsandcs', 'apply', 'reply', 'hl', '4', 'info']
# ['six', 'chances', 'win', 'cash', '100', 'pounds', 'txt', 'csh11', 'send', 'cost', '6days', 'tsandcs', 'apply', 'reply', 'hl', '4', 'info']
# ['urgent', '!', 'you', 'have', 'won', 'a', '1', 'week', 'free', 'membership', 'in', 'our', 'å£100,000', 'prize', 'jackpot', '!', 'txt', 'the', 'word', ':', 'claim', 'to', 'no', ':', '81010', 't', '&', 'c', 'www.dbuk.net', 'lccltd', 'pobox', '4403ldnw1a7rw18']
# ['urgent', 'you', 'have', 'won', 'a', '1', 'week', 'free', 'membership', 'in', 'our', 'prize', 'jackpot', 'txt', 'the', 'word', 'claim', 'to', 'no', '81010', 't', 'c', 'lccltd', 'pobox', '4403ldnw1a7rw18']
# ['urgent', '1', 'week', 'free', 'membership', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 'c', 'lccltd', 'pobox', '4403ldnw1a7rw18']
# ['i', "'ve", 'been', 'searching', 'for', 'the', 'right', 'words', 'to', 'thank', 'you', 'for', 'this', 'breather', '.', 'i', 'promise', 'i', 'wont', 'take', 'your', 'help', 'for', 'granted', 'and', 'will', 'fulfil', 'my', 'promise', '.', 'you', 'have', 'been', 'wonderful', 'and', 'a', 'blessing', 'at', 'all', 'times', '.']
# ['i', 'been', 'searching', 'for', 'the', 'right', 'words', 'to', 'thank', 'you', 'for', 'this', 'breather', 'i', 'promise', 'i', 'wont', 'take', 'your', 'help', 'for', 'granted', 'and', 'will', 'fulfil', 'my', 'promise', 'you', 'have', 'been', 'wonderful', 'and', 'a', 'blessing', 'at', 'all', 'times']
# ['searching', 'right', 'words', 'thank', 'breather', 'promise', 'wont', 'take', 'help', 'granted', 'fulfil', 'promise', 'wonderful', 'blessing', 'times']
# ['i', 'have', 'a', 'date', 'on', 'sunday', 'with', 'will', '!', '!']
# ['i', 'have', 'a', 'date', 'on', 'sunday', 'with', 'will']
# ['date', 'sunday']
# ['xxxmobilemovieclub', ':', 'to', 'use', 'your', 'credit', ',', 'click', 'the', 'wap', 'link', 'in', 'the', 'next', 'txt', 'message', 'or', 'click', 'here', '>', '>', 'http', ':', '//wap', '.', 'xxxmobilemovieclub.com', '?', 'n=qjkgighjjgcbl']
# ['xxxmobilemovieclub', 'to', 'use', 'your', 'credit', 'click', 'the', 'wap', 'link', 'in', 'the', 'next', 'txt', 'message', 'or', 'click', 'here', 'http']
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'next', 'txt', 'message', 'click', 'http']
# ['oh', 'k', '...', 'i', "'m", 'watching', 'here', ':', ')']
# ['oh', 'k', 'i', 'watching', 'here']
# ['oh', 'k', 'watching']
# ['eh', 'u', 'remember', 'how', '2', 'spell', 'his', 'name', '...', 'yes', 'i', 'did', '.', 'he', 'v', 'naughty', 'make', 'until', 'i', 'v', 'wet', '.']
# ['eh', 'u', 'remember', 'how', '2', 'spell', 'his', 'name', 'yes', 'i', 'did', 'he', 'v', 'naughty', 'make', 'until', 'i', 'v', 'wet']
# ['eh', 'u', 'remember', '2', 'spell', 'name', 'yes', 'v', 'naughty', 'make', 'v', 'wet']
# ['fine', 'if', 'thatåõs', 'the', 'way', 'u', 'feel', '.', 'thatåõs', 'the', 'way', 'its', 'gota', 'b']
# ['fine', 'if', 'thatåõs', 'the', 'way', 'u', 'feel', 'thatåõs', 'the', 'way', 'its', 'gota', 'b']
# ['fine', 'thatåõs', 'way', 'u', 'feel', 'thatåõs', 'way', 'gota', 'b']
# ['england', 'v', 'macedonia', '-', 'dont', 'miss', 'the', 'goals/team', 'news', '.', 'txt', 'ur', 'national', 'team', 'to', '87077', 'eg', 'england', 'to', '87077', 'try', ':', 'wales', ',', 'scotland', '4txt/ì¼1.20', 'poboxox36504w45wq', '16+']
# ['england', 'v', 'macedonia', 'dont', 'miss', 'the', 'news', 'txt', 'ur', 'national', 'team', 'to', '87077', 'eg', 'england', 'to', '87077', 'try', 'wales', 'scotland', 'poboxox36504w45wq']
# ['england', 'v', 'macedonia', 'dont', 'miss', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try', 'wales', 'scotland', 'poboxox36504w45wq']
# ['is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name', '?']
# ['is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name']
# ['seriously', 'spell', 'name']
# ['i\x89û÷m', 'going', 'to', 'try', 'for', '2', 'months', 'ha', 'ha', 'only', 'joking']
# ['going', 'to', 'try', 'for', '2', 'months', 'ha', 'ha', 'only', 'joking']
# ['going', 'try', '2', 'months', 'ha', 'ha', 'joking']
# ['so', 'ì_', 'pay', 'first', 'lar', '...', 'then', 'when', 'is', 'da', 'stock', 'comin', '...']
# ['so', 'pay', 'first', 'lar', 'then', 'when', 'is', 'da', 'stock', 'comin']
# ['pay', 'first', 'lar', 'da', 'stock', 'comin']
# ['aft', 'i', 'finish', 'my', 'lunch', 'then', 'i', 'go', 'str', 'down', 'lor', '.', 'ard', '3', 'smth', 'lor', '.', 'u', 'finish', 'ur', 'lunch', 'already', '?']
# ['aft', 'i', 'finish', 'my', 'lunch', 'then', 'i', 'go', 'str', 'down', 'lor', 'ard', '3', 'smth', 'lor', 'u', 'finish', 'ur', 'lunch', 'already']
# ['aft', 'finish', 'lunch', 'go', 'str', 'lor', 'ard', '3', 'smth', 'lor', 'u', 'finish', 'ur', 'lunch', 'already']
# ['ffffffffff', '.', 'alright', 'no', 'way', 'i', 'can', 'meet', 'up', 'with', 'you', 'sooner', '?']
# ['ffffffffff', 'alright', 'no', 'way', 'i', 'can', 'meet', 'up', 'with', 'you', 'sooner']
# ['ffffffffff', 'alright', 'way', 'meet', 'sooner']
# ['just', 'forced', 'myself', 'to', 'eat', 'a', 'slice', '.', 'i', "'m", 'really', 'not', 'hungry', 'tho', '.', 'this', 'sucks', '.', 'mark', 'is', 'getting', 'worried', '.', 'he', 'knows', 'i', "'m", 'sick', 'when', 'i', 'turn', 'down', 'pizza', '.', 'lol']
# ['just', 'forced', 'myself', 'to', 'eat', 'a', 'slice', 'i', 'really', 'not', 'hungry', 'tho', 'this', 'sucks', 'mark', 'is', 'getting', 'worried', 'he', 'knows', 'i', 'sick', 'when', 'i', 'turn', 'down', 'pizza', 'lol']
# ['forced', 'eat', 'slice', 'really', 'hungry', 'tho', 'sucks', 'mark', 'getting', 'worried', 'knows', 'sick', 'turn', 'pizza', 'lol']
# ['lol', 'your', 'always', 'so', 'convincing', '.']
# ['lol', 'your', 'always', 'so', 'convincing']
# ['lol', 'always', 'convincing']
# ['did', 'you', 'catch', 'the', 'bus', '?', 'are', 'you', 'frying', 'an', 'egg', '?', 'did', 'you', 'make', 'a', 'tea', '?', 'are', 'you', 'eating', 'your', 'mom', "'s", 'left', 'over', 'dinner', '?', 'do', 'you', 'feel', 'my', 'love', '?']
# ['did', 'you', 'catch', 'the', 'bus', 'are', 'you', 'frying', 'an', 'egg', 'did', 'you', 'make', 'a', 'tea', 'are', 'you', 'eating', 'your', 'mom', 'left', 'over', 'dinner', 'do', 'you', 'feel', 'my', 'love']
# ['catch', 'bus', 'frying', 'egg', 'make', 'tea', 'eating', 'mom', 'left', 'dinner', 'feel', 'love']
# ['i', "'m", 'back', '&', 'amp', ';', 'we', "'re", 'packing', 'the', 'car', 'now', ',', 'i', "'ll", 'let', 'you', 'know', 'if', 'there', "'s", 'room']
# ['i', 'back', 'amp', 'we', 'packing', 'the', 'car', 'now', 'i', 'let', 'you', 'know', 'if', 'there', 'room']
# ['back', 'amp', 'packing', 'car', 'let', 'know', 'room']
# ['ahhh', '.', 'work', '.', 'i', 'vaguely', 'remember', 'that', '!', 'what', 'does', 'it', 'feel', 'like', '?', 'lol']
# ['ahhh', 'work', 'i', 'vaguely', 'remember', 'that', 'what', 'does', 'it', 'feel', 'like', 'lol']
# ['ahhh', 'work', 'vaguely', 'remember', 'feel', 'like', 'lol']
# ['wait', 'that', "'s", 'still', 'not', 'all', 'that', 'clear', ',', 'were', 'you', 'not', 'sure', 'about', 'me', 'being', 'sarcastic', 'or', 'that', 'that', "'s", 'why', 'x', 'does', "n't", 'want', 'to', 'live', 'with', 'us']
# ['wait', 'that', 'still', 'not', 'all', 'that', 'clear', 'were', 'you', 'not', 'sure', 'about', 'me', 'being', 'sarcastic', 'or', 'that', 'that', 'why', 'x', 'does', 'want', 'to', 'live', 'with', 'us']
# ['wait', 'still', 'clear', 'sure', 'sarcastic', 'x', 'want', 'live', 'us']
# ['yeah', 'he', 'got', 'in', 'at', '2', 'and', 'was', 'v', 'apologetic', '.', 'n', 'had', 'fallen', 'out', 'and', 'she', 'was', 'actin', 'like', 'spoilt', 'child', 'and', 'he', 'got', 'caught', 'up', 'in', 'that', '.', 'till', '2', '!', 'but', 'we', 'wo', "n't", 'go', 'there', '!', 'not', 'doing', 'too', 'badly', 'cheers', '.', 'you', '?']
# ['yeah', 'he', 'got', 'in', 'at', '2', 'and', 'was', 'v', 'apologetic', 'n', 'had', 'fallen', 'out', 'and', 'she', 'was', 'actin', 'like', 'spoilt', 'child', 'and', 'he', 'got', 'caught', 'up', 'in', 'that', 'till', '2', 'but', 'we', 'wo', 'go', 'there', 'not', 'doing', 'too', 'badly', 'cheers', 'you']
# ['yeah', 'got', '2', 'v', 'apologetic', 'n', 'fallen', 'actin', 'like', 'spoilt', 'child', 'got', 'caught', 'till', '2', 'wo', 'go', 'badly', 'cheers']
# ['k', 'tell', 'me', 'anything', 'about', 'you', '.']
# ['k', 'tell', 'me', 'anything', 'about', 'you']
# ['k', 'tell', 'anything']
# ['for', 'fear', 'of', 'fainting', 'with', 'the', 'of', 'all', 'that', 'housework', 'you', 'just', 'did', '?', 'quick', 'have', 'a', 'cuppa']
# ['for', 'fear', 'of', 'fainting', 'with', 'the', 'of', 'all', 'that', 'housework', 'you', 'just', 'did', 'quick', 'have', 'a', 'cuppa']
# ['fear', 'fainting', 'housework', 'quick', 'cuppa']
# ['thanks', 'for', 'your', 'subscription', 'to', 'ringtone', 'uk', 'your', 'mobile', 'will', 'be', 'charged', 'å£5/month', 'please', 'confirm', 'by', 'replying', 'yes', 'or', 'no', '.', 'if', 'you', 'reply', 'no', 'you', 'will', 'not', 'be', 'charged']
# ['thanks', 'for', 'your', 'subscription', 'to', 'ringtone', 'uk', 'your', 'mobile', 'will', 'be', 'charged', 'please', 'confirm', 'by', 'replying', 'yes', 'or', 'no', 'if', 'you', 'reply', 'no', 'you', 'will', 'not', 'be', 'charged']
# ['thanks', 'subscription', 'ringtone', 'uk', 'mobile', 'charged', 'please', 'confirm', 'replying', 'yes', 'reply', 'charged']
# ['yup', '...', 'ok', 'i', 'go', 'home', 'look', 'at', 'the', 'timings', 'then', 'i', 'msg', 'ì_', 'again', '...', 'xuhui', 'going', 'to', 'learn', 'on', '2nd', 'may', 'too', 'but', 'her', 'lesson', 'is', 'at', '8am']
# ['yup', 'ok', 'i', 'go', 'home', 'look', 'at', 'the', 'timings', 'then', 'i', 'msg', 'again', 'xuhui', 'going', 'to', 'learn', 'on', '2nd', 'may', 'too', 'but', 'her', 'lesson', 'is', 'at', '8am']
# ['yup', 'ok', 'go', 'home', 'look', 'timings', 'msg', 'xuhui', 'going', 'learn', '2nd', 'may', 'lesson', '8am']
# ['oops', ',', 'i', "'ll", 'let', 'you', 'know', 'when', 'my', 'roommate', "'s", 'done']
# ['oops', 'i', 'let', 'you', 'know', 'when', 'my', 'roommate', 'done']
# ['oops', 'let', 'know', 'roommate', 'done']
# ['i', 'see', 'the', 'letter', 'b', 'on', 'my', 'car']
# ['i', 'see', 'the', 'letter', 'b', 'on', 'my', 'car']
# ['see', 'letter', 'b', 'car']
# ['anything', 'lor', '...', 'u', 'decide', '...']
# ['anything', 'lor', 'u', 'decide']
# ['anything', 'lor', 'u', 'decide']
# ['hello', '!', 'how', "'s", 'you', 'and', 'how', 'did', 'saturday', 'go', '?', 'i', 'was', 'just', 'texting', 'to', 'see', 'if', 'you', "'d", 'decided', 'to', 'do', 'anything', 'tomo', '.', 'not', 'that', 'i', "'m", 'trying', 'to', 'invite', 'myself', 'or', 'anything', '!']
# ['hello', 'how', 'you', 'and', 'how', 'did', 'saturday', 'go', 'i', 'was', 'just', 'texting', 'to', 'see', 'if', 'you', 'decided', 'to', 'do', 'anything', 'tomo', 'not', 'that', 'i', 'trying', 'to', 'invite', 'myself', 'or', 'anything']
# ['hello', 'saturday', 'go', 'texting', 'see', 'decided', 'anything', 'tomo', 'trying', 'invite', 'anything']
# ['pls', 'go', 'ahead', 'with', 'watts', '.', 'i', 'just', 'wanted', 'to', 'be', 'sure', '.', 'do', 'have', 'a', 'great', 'weekend', '.', 'abiola']
# ['pls', 'go', 'ahead', 'with', 'watts', 'i', 'just', 'wanted', 'to', 'be', 'sure', 'do', 'have', 'a', 'great', 'weekend', 'abiola']
# ['pls', 'go', 'ahead', 'watts', 'wanted', 'sure', 'great', 'weekend', 'abiola']
# ['did', 'i', 'forget', 'to', 'tell', 'you', '?', 'i', 'want', 'you', ',', 'i', 'need', 'you', ',', 'i', 'crave', 'you', '...', 'but', 'most', 'of', 'all', '...', 'i', 'love', 'you', 'my', 'sweet', 'arabian', 'steed', '...', 'mmmmmm', '...', 'yummy']
# ['did', 'i', 'forget', 'to', 'tell', 'you', 'i', 'want', 'you', 'i', 'need', 'you', 'i', 'crave', 'you', 'but', 'most', 'of', 'all', 'i', 'love', 'you', 'my', 'sweet', 'arabian', 'steed', 'mmmmmm', 'yummy']
# ['forget', 'tell', 'want', 'need', 'crave', 'love', 'sweet', 'arabian', 'steed', 'mmmmmm', 'yummy']
# ['07732584351', '-', 'rodger', 'burns', '-', 'msg', '=', 'we', 'tried', 'to', 'call', 'you', 're', 'your', 'reply', 'to', 'our', 'sms', 'for', 'a', 'free', 'nokia', 'mobile', '+', 'free', 'camcorder', '.', 'please', 'call', 'now', '08000930705', 'for', 'delivery', 'tomorrow']
# ['07732584351', 'rodger', 'burns', 'msg', 'we', 'tried', 'to', 'call', 'you', 're', 'your', 'reply', 'to', 'our', 'sms', 'for', 'a', 'free', 'nokia', 'mobile', 'free', 'camcorder', 'please', 'call', 'now', '08000930705', 'for', 'delivery', 'tomorrow']
# ['07732584351', 'rodger', 'burns', 'msg', 'tried', 'call', 'reply', 'sms', 'free', 'nokia', 'mobile', 'free', 'camcorder', 'please', 'call', '08000930705', 'delivery', 'tomorrow']
# ['who', 'are', 'you', 'seeing', '?']
# ['who', 'are', 'you', 'seeing']
# ['seeing']
# ['great', '!', 'i', 'hope', 'you', 'like', 'your', 'man', 'well', 'endowed', '.', 'i', 'am', '&', 'lt', ';', '#', '&', 'gt', ';', 'inches', '...']
# ['great', 'i', 'hope', 'you', 'like', 'your', 'man', 'well', 'endowed', 'i', 'am', 'lt', 'gt', 'inches']
# ['great', 'hope', 'like', 'man', 'well', 'endowed', 'lt', 'gt', 'inches']
# ['no', 'calls', '..', 'messages', '..', 'missed', 'calls']
# ['no', 'calls', 'messages', 'missed', 'calls']
# ['calls', 'messages', 'missed', 'calls']
# ['did', "n't", 'you', 'get', 'hep', 'b', 'immunisation', 'in', 'nigeria', '.']
# ['did', 'you', 'get', 'hep', 'b', 'immunisation', 'in', 'nigeria']
# ['get', 'hep', 'b', 'immunisation', 'nigeria']
# ['fair', 'enough', ',', 'anything', 'going', 'on', '?']
# ['fair', 'enough', 'anything', 'going', 'on']
# ['fair', 'enough', 'anything', 'going']
# ['yeah', 'hopefully', ',', 'if', 'tyler', 'ca', "n't", 'do', 'it', 'i', 'could', 'maybe', 'ask', 'around', 'a', 'bit']
# ['yeah', 'hopefully', 'if', 'tyler', 'ca', 'do', 'it', 'i', 'could', 'maybe', 'ask', 'around', 'a', 'bit']
# ['yeah', 'hopefully', 'tyler', 'ca', 'could', 'maybe', 'ask', 'around', 'bit']
# ['u', 'do', "n't", 'know', 'how', 'stubborn', 'i', 'am', '.', 'i', 'did', "n't", 'even', 'want', 'to', 'go', 'to', 'the', 'hospital', '.', 'i', 'kept', 'telling', 'mark', 'i', "'m", 'not', 'a', 'weak', 'sucker', '.', 'hospitals', 'are', 'for', 'weak', 'suckers', '.']
# ['u', 'do', 'know', 'how', 'stubborn', 'i', 'am', 'i', 'did', 'even', 'want', 'to', 'go', 'to', 'the', 'hospital', 'i', 'kept', 'telling', 'mark', 'i', 'not', 'a', 'weak', 'sucker', 'hospitals', 'are', 'for', 'weak', 'suckers']
# ['u', 'know', 'stubborn', 'even', 'want', 'go', 'hospital', 'kept', 'telling', 'mark', 'weak', 'sucker', 'hospitals', 'weak', 'suckers']
# ['what', 'you', 'thinked', 'about', 'me', '.', 'first', 'time', 'you', 'saw', 'me', 'in', 'class', '.']
# ['what', 'you', 'thinked', 'about', 'me', 'first', 'time', 'you', 'saw', 'me', 'in', 'class']
# ['thinked', 'first', 'time', 'saw', 'class']
# ['a', 'gram', 'usually', 'runs', 'like', '&', 'lt', ';', '#', '&', 'gt', ';', ',', 'a', 'half', 'eighth', 'is', 'smarter', 'though', 'and', 'gets', 'you', 'almost', 'a', 'whole', 'second', 'gram', 'for', '&', 'lt', ';', '#', '&', 'gt', ';']
# ['a', 'gram', 'usually', 'runs', 'like', 'lt', 'gt', 'a', 'half', 'eighth', 'is', 'smarter', 'though', 'and', 'gets', 'you', 'almost', 'a', 'whole', 'second', 'gram', 'for', 'lt', 'gt']
# ['gram', 'usually', 'runs', 'like', 'lt', 'gt', 'half', 'eighth', 'smarter', 'though', 'gets', 'almost', 'whole', 'second', 'gram', 'lt', 'gt']
# ['k', 'fyi', 'x', 'has', 'a', 'ride', 'early', 'tomorrow', 'morning', 'but', 'he', "'s", 'crashing', 'at', 'our', 'place', 'tonight']
# ['k', 'fyi', 'x', 'has', 'a', 'ride', 'early', 'tomorrow', 'morning', 'but', 'he', 'crashing', 'at', 'our', 'place', 'tonight']
# ['k', 'fyi', 'x', 'ride', 'early', 'tomorrow', 'morning', 'crashing', 'place', 'tonight']
# ['wow', '.', 'i', 'never', 'realized', 'that', 'you', 'were', 'so', 'embarassed', 'by', 'your', 'accomodations', '.', 'i', 'thought', 'you', 'liked', 'it', ',', 'since', 'i', 'was', 'doing', 'the', 'best', 'i', 'could', 'and', 'you', 'always', 'seemed', 'so', 'happy', 'about', '\\the', 'cave\\', "''", '.', 'i', "'m", 'sorry', 'i', 'did', "n't", 'and', 'do', "n't", 'have', 'more', 'to', 'give', '.', 'i', "'m", 'sorry', 'i', 'offered', '.', 'i', "'m", 'sorry', 'your', 'room', 'was', 'so', 'embarassing', '.', "''"]
# ['wow', 'i', 'never', 'realized', 'that', 'you', 'were', 'so', 'embarassed', 'by', 'your', 'accomodations', 'i', 'thought', 'you', 'liked', 'it', 'since', 'i', 'was', 'doing', 'the', 'best', 'i', 'could', 'and', 'you', 'always', 'seemed', 'so', 'happy', 'about', 'i', 'sorry', 'i', 'did', 'and', 'do', 'have', 'more', 'to', 'give', 'i', 'sorry', 'i', 'offered', 'i', 'sorry', 'your', 'room', 'was', 'so', 'embarassing']
# ['wow', 'never', 'realized', 'embarassed', 'accomodations', 'thought', 'liked', 'since', 'best', 'could', 'always', 'seemed', 'happy', 'sorry', 'give', 'sorry', 'offered', 'sorry', 'room', 'embarassing']
# ['sms', '.', 'ac', 'sptv', ':', 'the', 'new', 'jersey', 'devils', 'and', 'the', 'detroit', 'red', 'wings', 'play', 'ice', 'hockey', '.', 'correct', 'or', 'incorrect', '?', 'end', '?', 'reply', 'end', 'sptv']
# ['sms', 'ac', 'sptv', 'the', 'new', 'jersey', 'devils', 'and', 'the', 'detroit', 'red', 'wings', 'play', 'ice', 'hockey', 'correct', 'or', 'incorrect', 'end', 'reply', 'end', 'sptv']
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wings', 'play', 'ice', 'hockey', 'correct', 'incorrect', 'end', 'reply', 'end', 'sptv']
# ['do', 'you', 'know', 'what', 'mallika', 'sherawat', 'did', 'yesterday', '?', 'find', 'out', 'now', '@', '&', 'lt', ';', 'url', '&', 'gt', ';']
# ['do', 'you', 'know', 'what', 'mallika', 'sherawat', 'did', 'yesterday', 'find', 'out', 'now', 'lt', 'url', 'gt']
# ['know', 'mallika', 'sherawat', 'yesterday', 'find', 'lt', 'url', 'gt']
# ['congrats', '!', '1', 'year', 'special', 'cinema', 'pass', 'for', '2', 'is', 'yours', '.', 'call', '09061209465', 'now', '!', 'c', 'suprman', 'v', ',', 'matrix3', ',', 'starwars3', ',', 'etc', 'all', '4', 'free', '!', 'bx420-ip4-5we', '.', '150pm', '.', 'dont', 'miss', 'out', '!']
# ['congrats', '1', 'year', 'special', 'cinema', 'pass', 'for', '2', 'is', 'yours', 'call', '09061209465', 'now', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', 'all', '4', 'free', '150pm', 'dont', 'miss', 'out']
# ['congrats', '1', 'year', 'special', 'cinema', 'pass', '2', 'call', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4', 'free', '150pm', 'dont', 'miss']
# ['sorry', ',', 'i', "'ll", 'call', 'later', 'in', 'meeting', '.']
# ['sorry', 'i', 'call', 'later', 'in', 'meeting']
# ['sorry', 'call', 'later', 'meeting']
# ['tell', 'where', 'you', 'reached']
# ['tell', 'where', 'you', 'reached']
# ['tell', 'reached']
# ['yes', '..', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series', '.']
# ['yes', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series']
# ['yes', 'gauti', 'sehwag', 'odi', 'series']
# ['your', 'gon', 'na', 'have', 'to', 'pick', 'up', 'a', '$', '1', 'burger', 'for', 'yourself', 'on', 'your', 'way', 'home', '.', 'i', 'ca', "n't", 'even', 'move', '.', 'pain', 'is', 'killing', 'me', '.']
# ['your', 'gon', 'na', 'have', 'to', 'pick', 'up', 'a', '1', 'burger', 'for', 'yourself', 'on', 'your', 'way', 'home', 'i', 'ca', 'even', 'move', 'pain', 'is', 'killing', 'me']
# ['gon', 'na', 'pick', '1', 'burger', 'way', 'home', 'ca', 'even', 'move', 'pain', 'killing']
# ['ha', 'ha', 'ha', 'good', 'joke', '.', 'girls', 'are', 'situation', 'seekers', '.']
# ['ha', 'ha', 'ha', 'good', 'joke', 'girls', 'are', 'situation', 'seekers']
# ['ha', 'ha', 'ha', 'good', 'joke', 'girls', 'situation', 'seekers']
# ['its', 'a', 'part', 'of', 'checking', 'iq']
# ['its', 'a', 'part', 'of', 'checking', 'iq']
# ['part', 'checking', 'iq']
# ['sorry', 'my', 'roommates', 'took', 'forever', ',', 'it', 'ok', 'if', 'i', 'come', 'by', 'now', '?']
# ['sorry', 'my', 'roommates', 'took', 'forever', 'it', 'ok', 'if', 'i', 'come', 'by', 'now']
# ['sorry', 'roommates', 'took', 'forever', 'ok', 'come']
# ['ok', 'lar', 'i', 'double', 'check', 'wif', 'da', 'hair', 'dresser', 'already', 'he', 'said', 'wun', 'cut', 'v', 'short', '.', 'he', 'said', 'will', 'cut', 'until', 'i', 'look', 'nice', '.']
# ['ok', 'lar', 'i', 'double', 'check', 'wif', 'da', 'hair', 'dresser', 'already', 'he', 'said', 'wun', 'cut', 'v', 'short', 'he', 'said', 'will', 'cut', 'until', 'i', 'look', 'nice']
# ['ok', 'lar', 'double', 'check', 'wif', 'da', 'hair', 'dresser', 'already', 'said', 'wun', 'cut', 'v', 'short', 'said', 'cut', 'look', 'nice']
# ['as', 'a', 'valued', 'customer', ',', 'i', 'am', 'pleased', 'to', 'advise', 'you', 'that', 'following', 'recent', 'review', 'of', 'your', 'mob', 'no', '.', 'you', 'are', 'awarded', 'with', 'a', 'å£1500', 'bonus', 'prize', ',', 'call', '09066364589']
# ['as', 'a', 'valued', 'customer', 'i', 'am', 'pleased', 'to', 'advise', 'you', 'that', 'following', 'recent', 'review', 'of', 'your', 'mob', 'no', 'you', 'are', 'awarded', 'with', 'a', 'bonus', 'prize', 'call', '09066364589']
# ['valued', 'customer', 'pleased', 'advise', 'following', 'recent', 'review', 'mob', 'awarded', 'bonus', 'prize', 'call', '09066364589']
# ['today', 'is', '\\song', 'dedicated', 'day', '..', '\\', "''", 'which', 'song', 'will', 'u', 'dedicate', 'for', 'me', '?', 'send', 'this', 'to', 'all', 'ur', 'valuable', 'frnds', 'but', 'first', 'rply', 'me', '...', "''"]
# ['today', 'is', 'dedicated', 'day', 'which', 'song', 'will', 'u', 'dedicate', 'for', 'me', 'send', 'this', 'to', 'all', 'ur', 'valuable', 'frnds', 'but', 'first', 'rply', 'me']
# ['today', 'dedicated', 'day', 'song', 'u', 'dedicate', 'send', 'ur', 'valuable', 'frnds', 'first', 'rply']
# ['urgent', 'ur', 'awarded', 'a', 'complimentary', 'trip', 'to', 'eurodisinc', 'trav', ',', 'aco', '&', 'entry41', 'or', 'å£1000', '.', 'to', 'claim', 'txt', 'dis', 'to', '87121', '18+6', '*', 'å£1.50', '(', 'morefrmmob', '.', 'shracomorsglsuplt', ')', '10', ',', 'ls1', '3aj']
# ['urgent', 'ur', 'awarded', 'a', 'complimentary', 'trip', 'to', 'eurodisinc', 'trav', 'aco', 'entry41', 'or', 'to', 'claim', 'txt', 'dis', 'to', '87121', 'morefrmmob', 'shracomorsglsuplt', '10', 'ls1', '3aj']
# ['urgent', 'ur', 'awarded', 'complimentary', 'trip', 'eurodisinc', 'trav', 'aco', 'entry41', 'claim', 'txt', 'dis', '87121', 'morefrmmob', 'shracomorsglsuplt', '10', 'ls1', '3aj']
# ['did', 'you', 'hear', 'about', 'the', 'new', '\\divorce', 'barbie\\', "''", '?', 'it', 'comes', 'with', 'all', 'of', 'ken', "'s", 'stuff', '!', "''"]
# ['did', 'you', 'hear', 'about', 'the', 'new', 'it', 'comes', 'with', 'all', 'of', 'ken', 'stuff']
# ['hear', 'new', 'comes', 'ken', 'stuff']
# ['i', 'plane', 'to', 'give', 'on', 'this', 'month', 'end', '.']
# ['i', 'plane', 'to', 'give', 'on', 'this', 'month', 'end']
# ['plane', 'give', 'month', 'end']
# ['wah', 'lucky', 'man', '...', 'then', 'can', 'save', 'money', '...', 'hee', '...']
# ['wah', 'lucky', 'man', 'then', 'can', 'save', 'money', 'hee']
# ['wah', 'lucky', 'man', 'save', 'money', 'hee']
# ['finished', 'class', 'where', 'are', 'you', '.']
# ['finished', 'class', 'where', 'are', 'you']
# ['finished', 'class']
# ['hi', 'babe', 'im', 'at', 'home', 'now', 'wan', 'na', 'do', 'something', '?', 'xx']
# ['hi', 'babe', 'im', 'at', 'home', 'now', 'wan', 'na', 'do', 'something', 'xx']
# ['hi', 'babe', 'im', 'home', 'wan', 'na', 'something', 'xx']
# ['k', '..', 'k', ':', ')', 'where', 'are', 'you', '?', 'how', 'did', 'you', 'performed', '?']
# ['k', 'k', 'where', 'are', 'you', 'how', 'did', 'you', 'performed']
# ['k', 'k', 'performed']
# ['u', 'can', 'call', 'me', 'now', '...']
# ['u', 'can', 'call', 'me', 'now']
# ['u', 'call']
# ['i', 'am', 'waiting', 'machan', '.', 'call', 'me', 'once', 'you', 'free', '.']
# ['i', 'am', 'waiting', 'machan', 'call', 'me', 'once', 'you', 'free']
# ['waiting', 'machan', 'call', 'free']
# ['thats', 'cool', '.', 'i', 'am', 'a', 'gentleman', 'and', 'will', 'treat', 'you', 'with', 'dignity', 'and', 'respect', '.']
# ['thats', 'cool', 'i', 'am', 'a', 'gentleman', 'and', 'will', 'treat', 'you', 'with', 'dignity', 'and', 'respect']
# ['thats', 'cool', 'gentleman', 'treat', 'dignity', 'respect']
# ['i', 'like', 'you', 'peoples', 'very', 'much', ':', ')', 'but', 'am', 'very', 'shy', 'pa', '.']
# ['i', 'like', 'you', 'peoples', 'very', 'much', 'but', 'am', 'very', 'shy', 'pa']
# ['like', 'peoples', 'much', 'shy', 'pa']
# ['does', 'not', 'operate', 'after', '&', 'lt', ';', '#', '&', 'gt', ';', 'or', 'what']
# ['does', 'not', 'operate', 'after', 'lt', 'gt', 'or', 'what']
# ['operate', 'lt', 'gt']
# ['its', 'not', 'the', 'same', 'here', '.', 'still', 'looking', 'for', 'a', 'job', '.', 'how', 'much', 'do', 'ta', "'s", 'earn', 'there', '.']
# ['its', 'not', 'the', 'same', 'here', 'still', 'looking', 'for', 'a', 'job', 'how', 'much', 'do', 'ta', 'earn', 'there']
# ['still', 'looking', 'job', 'much', 'ta', 'earn']
# ['sorry', ',', 'i', "'ll", 'call', 'later']
# ['sorry', 'i', 'call', 'later']
# ['sorry', 'call', 'later']
# ['k.', 'did', 'you', 'call', 'me', 'just', 'now', 'ah', '?']
# ['did', 'you', 'call', 'me', 'just', 'now', 'ah']
# ['call', 'ah']
# ['ok', 'i', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi']
# ['ok', 'i', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi']
# ['ok', 'way', 'home', 'hi', 'hi']
# ['you', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man']
# ['you', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man']
# ['place', 'man']
# ['yup', 'next', 'stop', '.']
# ['yup', 'next', 'stop']
# ['yup', 'next', 'stop']
# ['i', 'call', 'you', 'later', ',', 'do', "n't", 'have', 'network', '.', 'if', 'urgnt', ',', 'sms', 'me', '.']
# ['i', 'call', 'you', 'later', 'do', 'have', 'network', 'if', 'urgnt', 'sms', 'me']
# ['call', 'later', 'network', 'urgnt', 'sms']
# ['for', 'real', 'when', 'u', 'getting', 'on', 'yo', '?', 'i', 'only', 'need', '2', 'more', 'tickets', 'and', 'one', 'more', 'jacket', 'and', 'i', "'m", 'done', '.', 'i', 'already', 'used', 'all', 'my', 'multis', '.']
# ['for', 'real', 'when', 'u', 'getting', 'on', 'yo', 'i', 'only', 'need', '2', 'more', 'tickets', 'and', 'one', 'more', 'jacket', 'and', 'i', 'done', 'i', 'already', 'used', 'all', 'my', 'multis']
# ['real', 'u', 'getting', 'yo', 'need', '2', 'tickets', 'one', 'jacket', 'done', 'already', 'used', 'multis']
# ['yes', 'i', 'started', 'to', 'send', 'requests', 'to', 'make', 'it', 'but', 'pain', 'came', 'back', 'so', 'i', "'m", 'back', 'in', 'bed', '.', 'double', 'coins', 'at', 'the', 'factory', 'too', '.', 'i', 'got', 'ta', 'cash', 'in', 'all', 'my', 'nitros', '.']
# ['yes', 'i', 'started', 'to', 'send', 'requests', 'to', 'make', 'it', 'but', 'pain', 'came', 'back', 'so', 'i', 'back', 'in', 'bed', 'double', 'coins', 'at', 'the', 'factory', 'too', 'i', 'got', 'ta', 'cash', 'in', 'all', 'my', 'nitros']
# ['yes', 'started', 'send', 'requests', 'make', 'pain', 'came', 'back', 'back', 'bed', 'double', 'coins', 'factory', 'got', 'ta', 'cash', 'nitros']
# ['i', "'m", 'really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe']
# ['i', 'really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe']
# ['really', 'still', 'tonight', 'babe']
# ['ela', 'kano.', ',', 'il', 'download', ',', 'come', 'wen', 'ur', 'free', '..']
# ['ela', 'il', 'download', 'come', 'wen', 'ur', 'free']
# ['ela', 'il', 'download', 'come', 'wen', 'ur', 'free']
# ['yeah', 'do', '!', 'don\x89û÷t', 'stand', 'to', 'close', 'tho-', 'you\x89û÷ll', 'catch', 'something', '!']
# ['yeah', 'do', 'stand', 'to', 'close', 'catch', 'something']
# ['yeah', 'stand', 'close', 'catch', 'something']
# ['sorry', 'to', 'be', 'a', 'pain', '.', 'is', 'it', 'ok', 'if', 'we', 'meet', 'another', 'night', '?', 'i', 'spent', 'late', 'afternoon', 'in', 'casualty', 'and', 'that', 'means', 'i', 'have', "n't", 'done', 'any', 'of', 'y', 'stuff42moro', 'and', 'that', 'includes', 'all', 'my', 'time', 'sheets', 'and', 'that', '.', 'sorry', '.']
# ['sorry', 'to', 'be', 'a', 'pain', 'is', 'it', 'ok', 'if', 'we', 'meet', 'another', 'night', 'i', 'spent', 'late', 'afternoon', 'in', 'casualty', 'and', 'that', 'means', 'i', 'have', 'done', 'any', 'of', 'y', 'stuff42moro', 'and', 'that', 'includes', 'all', 'my', 'time', 'sheets', 'and', 'that', 'sorry']
# ['sorry', 'pain', 'ok', 'meet', 'another', 'night', 'spent', 'late', 'afternoon', 'casualty', 'means', 'done', 'stuff42moro', 'includes', 'time', 'sheets', 'sorry']
# ['smile', 'in', 'pleasure', 'smile', 'in', 'pain', 'smile', 'when', 'trouble', 'pours', 'like', 'rain', 'smile', 'when', 'sum1', 'hurts', 'u', 'smile', 'becoz', 'someone', 'still', 'loves', 'to', 'see', 'u', 'smiling', '!', '!']
# ['smile', 'in', 'pleasure', 'smile', 'in', 'pain', 'smile', 'when', 'trouble', 'pours', 'like', 'rain', 'smile', 'when', 'sum1', 'hurts', 'u', 'smile', 'becoz', 'someone', 'still', 'loves', 'to', 'see', 'u', 'smiling']
# ['smile', 'pleasure', 'smile', 'pain', 'smile', 'trouble', 'pours', 'like', 'rain', 'smile', 'sum1', 'hurts', 'u', 'smile', 'becoz', 'someone', 'still', 'loves', 'see', 'u', 'smiling']
# ['please', 'call', 'our', 'customer', 'service', 'representative', 'on', '0800', '169', '6031', 'between', '10am-9pm', 'as', 'you', 'have', 'won', 'a', 'guaranteed', 'å£1000', 'cash', 'or', 'å£5000', 'prize', '!']
# ['please', 'call', 'our', 'customer', 'service', 'representative', 'on', '0800', '169', '6031', 'between', 'as', 'you', 'have', 'won', 'a', 'guaranteed', 'cash', 'or', 'prize']
# ['please', 'call', 'customer', 'service', 'representative', '0800', '169', '6031', 'guaranteed', 'cash', 'prize']
# ['havent', 'planning', 'to', 'buy', 'later', '.', 'i', 'check', 'already', 'lido', 'only', 'got', '530', 'show', 'in', 'e', 'afternoon', '.', 'u', 'finish', 'work', 'already', '?']
# ['havent', 'planning', 'to', 'buy', 'later', 'i', 'check', 'already', 'lido', 'only', 'got', '530', 'show', 'in', 'e', 'afternoon', 'u', 'finish', 'work', 'already']
# ['havent', 'planning', 'buy', 'later', 'check', 'already', 'lido', 'got', '530', 'show', 'e', 'afternoon', 'u', 'finish', 'work', 'already']
# ['your', 'free', 'ringtone', 'is', 'waiting', 'to', 'be', 'collected', '.', 'simply', 'text', 'the', 'password', '\\mix\\', "''", 'to', '85069', 'to', 'verify', '.', 'get', 'usher', 'and', 'britney', '.', 'fml']
# ['your', 'free', 'ringtone', 'is', 'waiting', 'to', 'be', 'collected', 'simply', 'text', 'the', 'password', 'to', '85069', 'to', 'verify', 'get', 'usher', 'and', 'britney', 'fml']
# ['free', 'ringtone', 'waiting', 'collected', 'simply', 'text', 'password', '85069', 'verify', 'get', 'usher', 'britney', 'fml']
# ['watching', 'telugu', 'movie', '..', 'wat', 'abt', 'u', '?']
# ['watching', 'telugu', 'movie', 'wat', 'abt', 'u']
# ['watching', 'telugu', 'movie', 'wat', 'abt', 'u']
# ['i', 'see', '.', 'when', 'we', 'finish', 'we', 'have', 'loads', 'of', 'loans', 'to', 'pay']
# ['i', 'see', 'when', 'we', 'finish', 'we', 'have', 'loads', 'of', 'loans', 'to', 'pay']
# ['see', 'finish', 'loads', 'loans', 'pay']
# ['hi', '.', 'wk', 'been', 'ok', '-', 'on', 'hols', 'now', '!', 'yes', 'on', 'for', 'a', 'bit', 'of', 'a', 'run', '.', 'forgot', 'that', 'i', 'have', 'hairdressers', 'appointment', 'at', 'four', 'so', 'need', 'to', 'get', 'home', 'n', 'shower', 'beforehand', '.', 'does', 'that', 'cause', 'prob', 'for', 'u', '?', '\\', "''", 'ham', "''"]
# ['hi', 'wk', 'been', 'ok', 'on', 'hols', 'now', 'yes', 'on', 'for', 'a', 'bit', 'of', 'a', 'run', 'forgot', 'that', 'i', 'have', 'hairdressers', 'appointment', 'at', 'four', 'so', 'need', 'to', 'get', 'home', 'n', 'shower', 'beforehand', 'does', 'that', 'cause', 'prob', 'for', 'u', 'ham']
# ['hi', 'wk', 'ok', 'hols', 'yes', 'bit', 'run', 'forgot', 'hairdressers', 'appointment', 'four', 'need', 'get', 'home', 'n', 'shower', 'beforehand', 'cause', 'prob', 'u', 'ham']
# ['please', 'do', "n't", 'text', 'me', 'anymore', '.', 'i', 'have', 'nothing', 'else', 'to', 'say', '.']
# ['please', 'do', 'text', 'me', 'anymore', 'i', 'have', 'nothing', 'else', 'to', 'say']
# ['please', 'text', 'anymore', 'nothing', 'else', 'say']
# ['okay', 'name', 'ur', 'price', 'as', 'long', 'as', 'its', 'legal', '!', 'wen', 'can', 'i', 'pick', 'them', 'up', '?', 'y', 'u', 'ave', 'x', 'ams', 'xx']
# ['okay', 'name', 'ur', 'price', 'as', 'long', 'as', 'its', 'legal', 'wen', 'can', 'i', 'pick', 'them', 'up', 'y', 'u', 'ave', 'x', 'ams', 'xx']
# ['okay', 'name', 'ur', 'price', 'long', 'legal', 'wen', 'pick', 'u', 'ave', 'x', 'ams', 'xx']
# ['i', "'m", 'still', 'looking', 'for', 'a', 'car', 'to', 'buy', '.', 'and', 'have', 'not', 'gone', '4the', 'driving', 'test', 'yet', '.']
# ['i', 'still', 'looking', 'for', 'a', 'car', 'to', 'buy', 'and', 'have', 'not', 'gone', '4the', 'driving', 'test', 'yet']
# ['still', 'looking', 'car', 'buy', 'gone', '4the', 'driving', 'test', 'yet']
# ['wow', '.', 'you', "'re", 'right', '!', 'i', 'did', "n't", 'mean', 'to', 'do', 'that', '.', 'i', 'guess', 'once', 'i', 'gave', 'up', 'on', 'boston', 'men', 'and', 'changed', 'my', 'search', 'location', 'to', 'nyc', ',', 'something', 'changed', '.', 'cuz', 'on', 'my', 'signin', 'page', 'it', 'still', 'says', 'boston', '.']
# ['wow', 'you', 'right', 'i', 'did', 'mean', 'to', 'do', 'that', 'i', 'guess', 'once', 'i', 'gave', 'up', 'on', 'boston', 'men', 'and', 'changed', 'my', 'search', 'location', 'to', 'nyc', 'something', 'changed', 'cuz', 'on', 'my', 'signin', 'page', 'it', 'still', 'says', 'boston']
# ['wow', 'right', 'mean', 'guess', 'gave', 'boston', 'men', 'changed', 'search', 'location', 'nyc', 'something', 'changed', 'cuz', 'signin', 'page', 'still', 'says', 'boston']
# ['umma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear']
# ['umma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear']
# ['umma', 'life', 'vava', 'umma', 'love', 'lot', 'dear']
# ['thanks', 'a', 'lot', 'for', 'your', 'wishes', 'on', 'my', 'birthday', '.', 'thanks', 'you', 'for', 'making', 'my', 'birthday', 'truly', 'memorable', '.']
# ['thanks', 'a', 'lot', 'for', 'your', 'wishes', 'on', 'my', 'birthday', 'thanks', 'you', 'for', 'making', 'my', 'birthday', 'truly', 'memorable']
# ['thanks', 'lot', 'wishes', 'birthday', 'thanks', 'making', 'birthday', 'truly', 'memorable']
# ['aight', ',', 'i', "'ll", 'hit', 'you', 'up', 'when', 'i', 'get', 'some', 'cash']
# ['aight', 'i', 'hit', 'you', 'up', 'when', 'i', 'get', 'some', 'cash']
# ['aight', 'hit', 'get', 'cash']
# ['how', 'would', 'my', 'ip', 'address', 'test', 'that', 'considering', 'my', 'computer', 'is', "n't", 'a', 'minecraft', 'server']
# ['how', 'would', 'my', 'ip', 'address', 'test', 'that', 'considering', 'my', 'computer', 'is', 'a', 'minecraft', 'server']
# ['would', 'ip', 'address', 'test', 'considering', 'computer', 'minecraft', 'server']
# ['i', 'know', '!', 'grumpy', 'old', 'people', '.', 'my', 'mom', 'was', 'like', 'you', 'better', 'not', 'be', 'lying', '.', 'then', 'again', 'i', 'am', 'always', 'the', 'one', 'to', 'play', 'jokes', '...']
# ['i', 'know', 'grumpy', 'old', 'people', 'my', 'mom', 'was', 'like', 'you', 'better', 'not', 'be', 'lying', 'then', 'again', 'i', 'am', 'always', 'the', 'one', 'to', 'play', 'jokes']
# ['know', 'grumpy', 'old', 'people', 'mom', 'like', 'better', 'lying', 'always', 'one', 'play', 'jokes']
# ['dont', 'worry', '.', 'i', 'guess', 'he', "'s", 'busy', '.']
# ['dont', 'worry', 'i', 'guess', 'he', 'busy']
# ['dont', 'worry', 'guess', 'busy']
# ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research', '?']
# ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research']
# ['plural', 'noun', 'research']
# ['going', 'for', 'dinner.msg', 'you', 'after', '.']
# ['going', 'for', 'you', 'after']
# ['going']
# ['i', "'m", 'ok', 'wif', 'it', 'cos', 'i', 'like', '2', 'try', 'new', 'things', '.', 'but', 'i', 'scared', 'u', 'dun', 'like', 'mah', '.', 'cos', 'u', 'said', 'not', 'too', 'loud', '.']
# ['i', 'ok', 'wif', 'it', 'cos', 'i', 'like', '2', 'try', 'new', 'things', 'but', 'i', 'scared', 'u', 'dun', 'like', 'mah', 'cos', 'u', 'said', 'not', 'too', 'loud']
# ['ok', 'wif', 'cos', 'like', '2', 'try', 'new', 'things', 'scared', 'u', 'dun', 'like', 'mah', 'cos', 'u', 'said', 'loud']
# ['gent', '!', 'we', 'are', 'trying', 'to', 'contact', 'you', '.', 'last', 'weekends', 'draw', 'shows', 'that', 'you', 'won', 'a', 'å£1000', 'prize', 'guaranteed', '.', 'call', '09064012160.', 'claim', 'code', 'k52', '.', 'valid', '12hrs', 'only', '.', '150ppm']
# ['gent', 'we', 'are', 'trying', 'to', 'contact', 'you', 'last', 'weekends', 'draw', 'shows', 'that', 'you', 'won', 'a', 'prize', 'guaranteed', 'call', 'claim', 'code', 'k52', 'valid', '12hrs', 'only', '150ppm']
# ['gent', 'trying', 'contact', 'last', 'weekends', 'draw', 'shows', 'prize', 'guaranteed', 'call', 'claim', 'code', 'k52', 'valid', '12hrs', '150ppm']
# ['wa', ',', 'ur', 'openin', 'sentence', 'very', 'formal', '...', 'anyway', ',', 'i', "'m", 'fine', 'too', ',', 'juz', 'tt', 'i', "'m", 'eatin', 'too', 'much', 'n', 'puttin', 'on', 'weight', '...', 'haha', '...', 'so', 'anythin', 'special', 'happened', '?']
# ['wa', 'ur', 'openin', 'sentence', 'very', 'formal', 'anyway', 'i', 'fine', 'too', 'juz', 'tt', 'i', 'eatin', 'too', 'much', 'n', 'puttin', 'on', 'weight', 'haha', 'so', 'anythin', 'special', 'happened']
# ['wa', 'ur', 'openin', 'sentence', 'formal', 'anyway', 'fine', 'juz', 'tt', 'eatin', 'much', 'n', 'puttin', 'weight', 'haha', 'anythin', 'special', 'happened']
# ['as', 'i', 'entered', 'my', 'cabin', 'my', 'pa', 'said', ',', '``', 'happy', "b'day", 'boss', '!', '!', "''", '.', 'i', 'felt', 'special', '.', 'she', 'askd', 'me', '4', 'lunch', '.', 'after', 'lunch', 'she', 'invited', 'me', 'to', 'her', 'apartment', '.', 'we', 'went', 'there', '.']
# ['as', 'i', 'entered', 'my', 'cabin', 'my', 'pa', 'said', 'happy', 'boss', 'i', 'felt', 'special', 'she', 'askd', 'me', '4', 'lunch', 'after', 'lunch', 'she', 'invited', 'me', 'to', 'her', 'apartment', 'we', 'went', 'there']
# ['entered', 'cabin', 'pa', 'said', 'happy', 'boss', 'felt', 'special', 'askd', '4', 'lunch', 'lunch', 'invited', 'apartment', 'went']
# ['you', 'are', 'a', 'winner', 'u', 'have', 'been', 'specially', 'selected', '2', 'receive', 'å£1000', 'or', 'a', '4', '*', 'holiday', '(', 'flights', 'inc', ')', 'speak', 'to', 'a', 'live', 'operator', '2', 'claim', '0871277810910p/min', '(', '18+', ')']
# ['you', 'are', 'a', 'winner', 'u', 'have', 'been', 'specially', 'selected', '2', 'receive', 'or', 'a', '4', 'holiday', 'flights', 'inc', 'speak', 'to', 'a', 'live', 'operator', '2', 'claim']
# ['winner', 'u', 'specially', 'selected', '2', 'receive', '4', 'holiday', 'flights', 'inc', 'speak', 'live', 'operator', '2', 'claim']
# ['goodo', '!', 'yes', 'we', 'must', 'speak', 'friday', '-', 'egg-potato', 'ratio', 'for', 'tortilla', 'needed', '!']
# ['goodo', 'yes', 'we', 'must', 'speak', 'friday', 'ratio', 'for', 'tortilla', 'needed']
# ['goodo', 'yes', 'must', 'speak', 'friday', 'ratio', 'tortilla', 'needed']
# ['hmm', '...', 'my', 'uncle', 'just', 'informed', 'me', 'that', 'he', "'s", 'paying', 'the', 'school', 'directly', '.', 'so', 'pls', 'buy', 'food', '.']
# ['hmm', 'my', 'uncle', 'just', 'informed', 'me', 'that', 'he', 'paying', 'the', 'school', 'directly', 'so', 'pls', 'buy', 'food']
# ['hmm', 'uncle', 'informed', 'paying', 'school', 'directly', 'pls', 'buy', 'food']
# ['private', '!', 'your', '2004', 'account', 'statement', 'for', '07742676969', 'shows', '786', 'unredeemed', 'bonus', 'points', '.', 'to', 'claim', 'call', '08719180248', 'identifier', 'code', ':', '45239', 'expires']
# ['private', 'your', '2004', 'account', 'statement', 'for', '07742676969', 'shows', '786', 'unredeemed', 'bonus', 'points', 'to', 'claim', 'call', '08719180248', 'identifier', 'code', '45239', 'expires']
# ['private', '2004', 'account', 'statement', '07742676969', 'shows', '786', 'unredeemed', 'bonus', 'points', 'claim', 'call', '08719180248', 'identifier', 'code', '45239', 'expires']
# ['urgent', '!', 'your', 'mobile', 'no', '.', 'was', 'awarded', 'å£2000', 'bonus', 'caller', 'prize', 'on', '5/9/03', 'this', 'is', 'our', 'final', 'try', 'to', 'contact', 'u', '!', 'call', 'from', 'landline', '09064019788', 'box42wr29c', ',', '150ppm']
# ['urgent', 'your', 'mobile', 'no', 'was', 'awarded', 'bonus', 'caller', 'prize', 'on', 'this', 'is', 'our', 'final', 'try', 'to', 'contact', 'u', 'call', 'from', 'landline', '09064019788', 'box42wr29c', '150ppm']
# ['urgent', 'mobile', 'awarded', 'bonus', 'caller', 'prize', 'final', 'try', 'contact', 'u', 'call', 'landline', '09064019788', 'box42wr29c', '150ppm']
# ['here', 'is', 'my', 'new', 'address', '-apples', '&', 'pairs', '&', 'all', 'that', 'malarky']
# ['here', 'is', 'my', 'new', 'address', 'pairs', 'all', 'that', 'malarky']
# ['new', 'address', 'pairs', 'malarky']
# ['todays', 'voda', 'numbers', 'ending', '7548', 'are', 'selected', 'to', 'receive', 'a', '$', '350', 'award', '.', 'if', 'you', 'have', 'a', 'match', 'please', 'call', '08712300220', 'quoting', 'claim', 'code', '4041', 'standard', 'rates', 'app']
# ['todays', 'voda', 'numbers', 'ending', '7548', 'are', 'selected', 'to', 'receive', 'a', '350', 'award', 'if', 'you', 'have', 'a', 'match', 'please', 'call', '08712300220', 'quoting', 'claim', 'code', '4041', 'standard', 'rates', 'app']
# ['todays', 'voda', 'numbers', 'ending', '7548', 'selected', 'receive', '350', 'award', 'match', 'please', 'call', '08712300220', 'quoting', 'claim', 'code', '4041', 'standard', 'rates', 'app']
# ['i', 'am', 'going', 'to', 'sao', 'mu', 'today', '.', 'will', 'be', 'done', 'only', 'at', '12']
# ['i', 'am', 'going', 'to', 'sao', 'mu', 'today', 'will', 'be', 'done', 'only', 'at', '12']
# ['going', 'sao', 'mu', 'today', 'done', '12']
# ['ìï', 'predict', 'wat', 'time', 'ì_', "'ll", 'finish', 'buying', '?']
# ['ìï', 'predict', 'wat', 'time', 'finish', 'buying']
# ['ìï', 'predict', 'wat', 'time', 'finish', 'buying']
# ['good', 'stuff', ',', 'will', 'do', '.']
# ['good', 'stuff', 'will', 'do']
# ['good', 'stuff']
# ['just', 'so', 'that', 'you', 'know', ',', 'yetunde', 'has', "n't", 'sent', 'money', 'yet', '.', 'i', 'just', 'sent', 'her', 'a', 'text', 'not', 'to', 'bother', 'sending', '.', 'so', 'its', 'over', ',', 'you', 'dont', 'have', 'to', 'involve', 'yourself', 'in', 'anything', '.', 'i', 'should', "n't", 'have', 'imposed', 'anything', 'on', 'you', 'in', 'the', 'first', 'place', 'so', 'for', 'that', ',', 'i', 'apologise', '.']
# ['just', 'so', 'that', 'you', 'know', 'yetunde', 'has', 'sent', 'money', 'yet', 'i', 'just', 'sent', 'her', 'a', 'text', 'not', 'to', 'bother', 'sending', 'so', 'its', 'over', 'you', 'dont', 'have', 'to', 'involve', 'yourself', 'in', 'anything', 'i', 'should', 'have', 'imposed', 'anything', 'on', 'you', 'in', 'the', 'first', 'place', 'so', 'for', 'that', 'i', 'apologise']
# ['know', 'yetunde', 'sent', 'money', 'yet', 'sent', 'text', 'bother', 'sending', 'dont', 'involve', 'anything', 'imposed', 'anything', 'first', 'place', 'apologise']
# ['are', 'you', 'there', 'in', 'room', '.']
# ['are', 'you', 'there', 'in', 'room']
# ['room']
# ['hey', 'girl', '.', 'how', 'r', 'u', '?', 'hope', 'u', 'r', 'well', 'me', 'an', 'del', 'r', 'bak', '!', 'again', 'long', 'time', 'no', 'c', '!', 'give', 'me', 'a', 'call', 'sum', 'time', 'from', 'lucyxx']
# ...
# ['no', '.', 'i', 'dont', 'want', 'to', 'hear', 'anything']
# ['no', 'i', 'dont', 'want', 'to', 'hear', 'anything']
# ['dont', 'want', 'hear', 'anything']
# ['you', 'are', 'a', 'big', 'chic', '.', 'common', '.', 'declare']
# ['you', 'are', 'a', 'big', 'chic', 'common', 'declare']
# ['big', 'chic', 'common', 'declare']
# ['thats', 'cool', '.', 'i', 'want', 'to', 'please', 'you', '...']
# ['thats', 'cool', 'i', 'want', 'to', 'please', 'you']
# ['thats', 'cool', 'want', 'please']
# ['going', 'to', 'join', 'tomorrow', '.']
# ['going', 'to', 'join', 'tomorrow']
# ['going', 'join', 'tomorrow']
# ['i', 'want', 'to', 'tell', 'you', 'how', 'bad', 'i', 'feel', 'that', 'basically', 'the', 'only', 'times', 'i', 'text', 'you', 'lately', 'are', 'when', 'i', 'need', 'drugs']
# ['i', 'want', 'to', 'tell', 'you', 'how', 'bad', 'i', 'feel', 'that', 'basically', 'the', 'only', 'times', 'i', 'text', 'you', 'lately', 'are', 'when', 'i', 'need', 'drugs']
# ['want', 'tell', 'bad', 'feel', 'basically', 'times', 'text', 'lately', 'need', 'drugs']
# ['private', '!', 'your', '2003', 'account', 'statement', 'for', 'shows', '800', 'un-redeemed', 's.i.m', '.', 'points', '.', 'call', '08718738001', 'identifier', 'code', ':', '49557', 'expires', '26/11/04']
# ['private', 'your', '2003', 'account', 'statement', 'for', 'shows', '800', 'points', 'call', '08718738001', 'identifier', 'code', '49557', 'expires']
# ['private', '2003', 'account', 'statement', 'shows', '800', 'points', 'call', '08718738001', 'identifier', 'code', '49557', 'expires']
# ['total', 'disappointment', ',', 'when', 'i', 'texted', 'you', 'was', 'the', 'craziest', 'shit', 'got', ':', '(']
# ['total', 'disappointment', 'when', 'i', 'texted', 'you', 'was', 'the', 'craziest', 'shit', 'got']
# ['total', 'disappointment', 'texted', 'craziest', 'shit', 'got']
# ['its', 'just', 'the', 'effect', 'of', 'irritation', '.', 'just', 'ignore', 'it']
# ['its', 'just', 'the', 'effect', 'of', 'irritation', 'just', 'ignore', 'it']
# ['effect', 'irritation', 'ignore']
# ['what', 'about', 'this', 'one', 'then', '.']
# ['what', 'about', 'this', 'one', 'then']
# ['one']
# ['i', 'think', 'that', 'tantrum', "'s", 'finished', 'so', 'yeah', 'i', "'ll", 'be', 'by', 'at', 'some', 'point']
# ['i', 'think', 'that', 'tantrum', 'finished', 'so', 'yeah', 'i', 'be', 'by', 'at', 'some', 'point']
# ['think', 'tantrum', 'finished', 'yeah', 'point']
# ['compliments', 'to', 'you', '.', 'was', 'away', 'from', 'the', 'system', '.', 'how', 'your', 'side', '.']
# ['compliments', 'to', 'you', 'was', 'away', 'from', 'the', 'system', 'how', 'your', 'side']
# ['compliments', 'away', 'system', 'side']
# ['happened', 'here', 'while', 'you', 'were', 'adventuring']
# ['happened', 'here', 'while', 'you', 'were', 'adventuring']
# ['happened', 'adventuring']
# ['hey', 'chief', ',', 'can', 'you', 'give', 'me', 'a', 'bell', 'when', 'you', 'get', 'this', '.', 'need', 'to', 'talk', 'to', 'you', 'about', 'this', 'royal', 'visit', 'on', 'the', '1st', 'june', '.']
# ['hey', 'chief', 'can', 'you', 'give', 'me', 'a', 'bell', 'when', 'you', 'get', 'this', 'need', 'to', 'talk', 'to', 'you', 'about', 'this', 'royal', 'visit', 'on', 'the', '1st', 'june']
# ['hey', 'chief', 'give', 'bell', 'get', 'need', 'talk', 'royal', 'visit', '1st', 'june']
# ['ok', 'which', 'your', 'another', 'number']
# ['ok', 'which', 'your', 'another', 'number']
# ['ok', 'another', 'number']
# ['aiyah', 'ok', 'wat', 'as', 'long', 'as', 'got', 'improve', 'can', 'already', 'wat', '...']
# ['aiyah', 'ok', 'wat', 'as', 'long', 'as', 'got', 'improve', 'can', 'already', 'wat']
# ['aiyah', 'ok', 'wat', 'long', 'got', 'improve', 'already', 'wat']
# ['want', 'explicit', 'sex', 'in', '30', 'secs', '?', 'ring', '02073162414', 'now', '!', 'costs', '20p/min', 'gsex', 'pobox', '2667', 'wc1n', '3xx']
# ['want', 'explicit', 'sex', 'in', '30', 'secs', 'ring', '02073162414', 'now', 'costs', 'gsex', 'pobox', '2667', 'wc1n', '3xx']
# ['want', 'explicit', 'sex', '30', 'secs', 'ring', '02073162414', 'costs', 'gsex', 'pobox', '2667', 'wc1n', '3xx']
# ['i', 'ca', "n't", 'believe', 'how', 'attached', 'i', 'am', 'to', 'seeing', 'you', 'every', 'day', '.', 'i', 'know', 'you', 'will', 'do', 'the', 'best', 'you', 'can', 'to', 'get', 'to', 'me', 'babe', '.', 'i', 'will', 'go', 'to', 'teach', 'my', 'class', 'at', 'your', 'midnight']
# ['i', 'ca', 'believe', 'how', 'attached', 'i', 'am', 'to', 'seeing', 'you', 'every', 'day', 'i', 'know', 'you', 'will', 'do', 'the', 'best', 'you', 'can', 'to', 'get', 'to', 'me', 'babe', 'i', 'will', 'go', 'to', 'teach', 'my', 'class', 'at', 'your', 'midnight']
# ['ca', 'believe', 'attached', 'seeing', 'every', 'day', 'know', 'best', 'get', 'babe', 'go', 'teach', 'class', 'midnight']
# ['asked', '3mobile', 'if', '0870', 'chatlines', 'inclu', 'in', 'free', 'mins', '.', 'india', 'cust', 'servs', 'sed', 'yes', '.', 'l8er', 'got', 'mega', 'bill', '.', '3', 'dont', 'giv', 'a', 'shit', '.', 'bailiff', 'due', 'in', 'days', '.', 'i', 'o', 'å£250', '3', 'want', 'å£800']
# ['asked', '3mobile', 'if', '0870', 'chatlines', 'inclu', 'in', 'free', 'mins', 'india', 'cust', 'servs', 'sed', 'yes', 'l8er', 'got', 'mega', 'bill', '3', 'dont', 'giv', 'a', 'shit', 'bailiff', 'due', 'in', 'days', 'i', 'o', '3', 'want']
# ['asked', '3mobile', '0870', 'chatlines', 'inclu', 'free', 'mins', 'india', 'cust', 'servs', 'sed', 'yes', 'l8er', 'got', 'mega', 'bill', '3', 'dont', 'giv', 'shit', 'bailiff', 'due', 'days', '3', 'want']
# ['yeah', 'it', "'s", 'jus', 'rite', '...']
# ['yeah', 'it', 'jus', 'rite']
# ['yeah', 'jus', 'rite']
# ['armand', 'says', 'get', 'your', 'ass', 'over', 'to', 'epsilon']
# ['armand', 'says', 'get', 'your', 'ass', 'over', 'to', 'epsilon']
# ['armand', 'says', 'get', 'ass', 'epsilon']
# ['u', 'still', 'havent', 'got', 'urself', 'a', 'jacket', 'ah', '?']
# ['u', 'still', 'havent', 'got', 'urself', 'a', 'jacket', 'ah']
# ['u', 'still', 'havent', 'got', 'urself', 'jacket', 'ah']
# ['i', "'m", 'taking', 'derek', '&', 'amp', ';', 'taylor', 'to', 'walmart', ',', 'if', 'i', "'m", 'not', 'back', 'by', 'the', 'time', 'you', "'re", 'done', 'just', 'leave', 'the', 'mouse', 'on', 'my', 'desk', 'and', 'i', "'ll", 'text', 'you', 'when', 'priscilla', "'s", 'ready']
# ['i', 'taking', 'derek', 'amp', 'taylor', 'to', 'walmart', 'if', 'i', 'not', 'back', 'by', 'the', 'time', 'you', 'done', 'just', 'leave', 'the', 'mouse', 'on', 'my', 'desk', 'and', 'i', 'text', 'you', 'when', 'priscilla', 'ready']
# ['taking', 'derek', 'amp', 'taylor', 'walmart', 'back', 'time', 'done', 'leave', 'mouse', 'desk', 'text', 'priscilla', 'ready']
# ['hi', 'its', 'in', 'durban', 'are', 'you', 'still', 'on', 'this', 'number']
# ['hi', 'its', 'in', 'durban', 'are', 'you', 'still', 'on', 'this', 'number']
# ['hi', 'durban', 'still', 'number']
# ['ic', '.', 'there', 'are', 'a', 'lotta', 'childporn', 'cars', 'then', '.']
# ['ic', 'there', 'are', 'a', 'lotta', 'childporn', 'cars', 'then']
# ['ic', 'lotta', 'childporn', 'cars']
# ['had', 'your', 'contract', 'mobile', '11', 'mnths', '?', 'latest', 'motorola', ',', 'nokia', 'etc', '.', 'all', 'free', '!', 'double', 'mins', '&', 'text', 'on', 'orange', 'tariffs', '.', 'text', 'yes', 'for', 'callback', ',', 'no', 'to', 'remove', 'from', 'records', '.']
# ['had', 'your', 'contract', 'mobile', '11', 'mnths', 'latest', 'motorola', 'nokia', 'etc', 'all', 'free', 'double', 'mins', 'text', 'on', 'orange', 'tariffs', 'text', 'yes', 'for', 'callback', 'no', 'to', 'remove', 'from', 'records']
# ['contract', 'mobile', '11', 'mnths', 'latest', 'motorola', 'nokia', 'etc', 'free', 'double', 'mins', 'text', 'orange', 'tariffs', 'text', 'yes', 'callback', 'remove', 'records']
# ['no', ',', 'i', 'was', 'trying', 'it', 'all', 'weekend', ';', 'v']
# ['no', 'i', 'was', 'trying', 'it', 'all', 'weekend', 'v']
# ['trying', 'weekend', 'v']
# ['you', 'know', ',', 'wot', 'people', 'wear', '.', 't', 'shirts', ',', 'jumpers', ',', 'hat', ',', 'belt', ',', 'is', 'all', 'we', 'know', '.', 'we', 'r', 'at', 'cribbs']
# ['you', 'know', 'wot', 'people', 'wear', 't', 'shirts', 'jumpers', 'hat', 'belt', 'is', 'all', 'we', 'know', 'we', 'r', 'at', 'cribbs']
# ['know', 'wot', 'people', 'wear', 'shirts', 'jumpers', 'hat', 'belt', 'know', 'r', 'cribbs']
# ['cool', ',', 'what', 'time', 'you', 'think', 'you', 'can', 'get', 'here', '?']
# ['cool', 'what', 'time', 'you', 'think', 'you', 'can', 'get', 'here']
# ['cool', 'time', 'think', 'get']
# ['wen', 'did', 'you', 'get', 'so', 'spiritual', 'and', 'deep', '.', 'that', "'s", 'great']
# ['wen', 'did', 'you', 'get', 'so', 'spiritual', 'and', 'deep', 'that', 'great']
# ['wen', 'get', 'spiritual', 'deep', 'great']
# ['have', 'a', 'safe', 'trip', 'to', 'nigeria', '.', 'wish', 'you', 'happiness', 'and', 'very', 'soon', 'company', 'to', 'share', 'moments', 'with']
# ['have', 'a', 'safe', 'trip', 'to', 'nigeria', 'wish', 'you', 'happiness', 'and', 'very', 'soon', 'company', 'to', 'share', 'moments', 'with']
# ['safe', 'trip', 'nigeria', 'wish', 'happiness', 'soon', 'company', 'share', 'moments']
# ['well', 'keep', 'in', 'mind', 'i', "'ve", 'only', 'got', 'enough', 'gas', 'for', 'one', 'more', 'round', 'trip', 'barring', 'a', 'sudden', 'influx', 'of', 'cash']
# ['well', 'keep', 'in', 'mind', 'i', 'only', 'got', 'enough', 'gas', 'for', 'one', 'more', 'round', 'trip', 'barring', 'a', 'sudden', 'influx', 'of', 'cash']
# ['well', 'keep', 'mind', 'got', 'enough', 'gas', 'one', 'round', 'trip', 'barring', 'sudden', 'influx', 'cash']
# ['yeh', '.', 'indians', 'was', 'nice', '.', 'tho', 'it', 'did', 'kane', 'me', 'off', 'a', 'bit', 'he', 'he', '.', 'we', 'shud', 'go', 'out', '4', 'a', 'drink', 'sometime', 'soon', '.', 'mite', 'hav', '2', 'go', '2', 'da', 'works', '4', 'a', 'laugh', 'soon', '.', 'love', 'pete', 'x', 'x']
# ['yeh', 'indians', 'was', 'nice', 'tho', 'it', 'did', 'kane', 'me', 'off', 'a', 'bit', 'he', 'he', 'we', 'shud', 'go', 'out', '4', 'a', 'drink', 'sometime', 'soon', 'mite', 'hav', '2', 'go', '2', 'da', 'works', '4', 'a', 'laugh', 'soon', 'love', 'pete', 'x', 'x']
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', 'go', '4', 'drink', 'sometime', 'soon', 'mite', 'hav', '2', 'go', '2', 'da', 'works', '4', 'laugh', 'soon', 'love', 'pete', 'x', 'x']
# ['yes', 'i', 'have', '.', 'so', 'that', "'s", 'why', 'u', 'texted', '.', 'pshew', '...', 'missing', 'you', 'so', 'much']
# ['yes', 'i', 'have', 'so', 'that', 'why', 'u', 'texted', 'pshew', 'missing', 'you', 'so', 'much']
# ['yes', 'u', 'texted', 'pshew', 'missing', 'much']
# ['no', '.', 'i', 'meant', 'the', 'calculation', 'is', 'the', 'same', '.', 'that', '&', 'lt', ';', '#', '&', 'gt', ';', 'units', 'at', '&', 'lt', ';', '#', '&', 'gt', ';', '.', 'this', 'school', 'is', 'really', 'expensive', '.', 'have', 'you', 'started', 'practicing', 'your', 'accent', '.', 'because', 'its', 'important', '.', 'and', 'have', 'you', 'decided', 'if', 'you', 'are', 'doing', '4years', 'of', 'dental', 'school', 'or', 'if', 'you', "'ll", 'just', 'do', 'the', 'nmde', 'exam', '.']
# ['no', 'i', 'meant', 'the', 'calculation', 'is', 'the', 'same', 'that', 'lt', 'gt', 'units', 'at', 'lt', 'gt', 'this', 'school', 'is', 'really', 'expensive', 'have', 'you', 'started', 'practicing', 'your', 'accent', 'because', 'its', 'important', 'and', 'have', 'you', 'decided', 'if', 'you', 'are', 'doing', '4years', 'of', 'dental', 'school', 'or', 'if', 'you', 'just', 'do', 'the', 'nmde', 'exam']
# ['meant', 'calculation', 'lt', 'gt', 'units', 'lt', 'gt', 'school', 'really', 'expensive', 'started', 'practicing', 'accent', 'important', 'decided', '4years', 'dental', 'school', 'nmde', 'exam']
# ['if', 'you', 'are', "n't", 'here', 'in', 'the', 'next', '&', 'lt', ';', '#', '&', 'gt', ';', 'hours', 'imma', 'flip', 'my', 'shit']
# ['if', 'you', 'are', 'here', 'in', 'the', 'next', 'lt', 'gt', 'hours', 'imma', 'flip', 'my', 'shit']
# ['next', 'lt', 'gt', 'hours', 'imma', 'flip', 'shit']
# ['anything', 'lor', '.', 'juz', 'both', 'of', 'us', 'lor', '.']
# ['anything', 'lor', 'juz', 'both', 'of', 'us', 'lor']
# ['anything', 'lor', 'juz', 'us', 'lor']
# ['get', 'me', 'out', 'of', 'this', 'dump', 'heap', '.', 'my', 'mom', 'decided', 'to', 'come', 'to', 'lowes', '.', 'boring', '.']
# ['get', 'me', 'out', 'of', 'this', 'dump', 'heap', 'my', 'mom', 'decided', 'to', 'come', 'to', 'lowes', 'boring']
# ['get', 'dump', 'heap', 'mom', 'decided', 'come', 'lowes', 'boring']
# ['ok', 'lor', '...', 'sony', 'ericsson', 'salesman', '...', 'i', 'ask', 'shuhui', 'then', 'she', 'say', 'quite', 'gd', '2', 'use', 'so', 'i', 'considering', '...']
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'i', 'ask', 'shuhui', 'then', 'she', 'say', 'quite', 'gd', '2', 'use', 'so', 'i', 'considering']
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'ask', 'shuhui', 'say', 'quite', 'gd', '2', 'use', 'considering']
# ['ard', '6', 'like', 'dat', 'lor', '.']
# ['ard', '6', 'like', 'dat', 'lor']
# ['ard', '6', 'like', 'dat', 'lor']
# ['why', 'do', "n't", 'you', 'wait', "'til", 'at', 'least', 'wednesday', 'to', 'see', 'if', 'you', 'get', 'your', '.']
# ['why', 'do', 'you', 'wait', 'at', 'least', 'wednesday', 'to', 'see', 'if', 'you', 'get', 'your']
# ['wait', 'least', 'wednesday', 'see', 'get']
# ['huh', 'y', 'lei', '...']
# ['huh', 'y', 'lei']
# ['huh', 'lei']
# ['reminder', 'from', 'o2', ':', 'to', 'get', '2.50', 'pounds', 'free', 'call', 'credit', 'and', 'details', 'of', 'great', 'offers', 'pls', 'reply', '2', 'this', 'text', 'with', 'your', 'valid', 'name', ',', 'house', 'no', 'and', 'postcode']
# ['reminder', 'from', 'o2', 'to', 'get', 'pounds', 'free', 'call', 'credit', 'and', 'details', 'of', 'great', 'offers', 'pls', 'reply', '2', 'this', 'text', 'with', 'your', 'valid', 'name', 'house', 'no', 'and', 'postcode']
# ['reminder', 'o2', 'get', 'pounds', 'free', 'call', 'credit', 'details', 'great', 'offers', 'pls', 'reply', '2', 'text', 'valid', 'name', 'house', 'postcode']
# ['this', 'is', 'the', '2nd', 'time', 'we', 'have', 'tried', '2', 'contact', 'u.', 'u', 'have', 'won', 'the', 'å£750', 'pound', 'prize', '.', '2', 'claim', 'is', 'easy', ',', 'call', '087187272008', 'now1', '!', 'only', '10p', 'per', 'minute', '.', 'bt-national-rate', '.']
# ['this', 'is', 'the', '2nd', 'time', 'we', 'have', 'tried', '2', 'contact', 'u', 'have', 'won', 'the', 'pound', 'prize', '2', 'claim', 'is', 'easy', 'call', '087187272008', 'now1', 'only', '10p', 'per', 'minute']
# ['2nd', 'time', 'tried', '2', 'contact', 'u', 'pound', 'prize', '2', 'claim', 'easy', 'call', '087187272008', 'now1', '10p', 'per', 'minute']
# ['will', 'ì_', 'b', 'going', 'to', 'esplanade', 'fr', 'home', '?']
# ['will', 'b', 'going', 'to', 'esplanade', 'fr', 'home']
# ['b', 'going', 'esplanade', 'fr', 'home']
# ['pity', ',', '*', 'was', 'in', 'mood', 'for', 'that', '.', 'so', '...', 'any', 'other', 'suggestions', '?']
# ['pity', 'was', 'in', 'mood', 'for', 'that', 'so', 'any', 'other', 'suggestions']
# ['pity', 'mood', 'suggestions']
# ['the', 'guy', 'did', 'some', 'bitching', 'but', 'i', 'acted', 'like', 'i', "'d", 'be', 'interested', 'in', 'buying', 'something', 'else', 'next', 'week', 'and', 'he', 'gave', 'it', 'to', 'us', 'for', 'free']
# ['the', 'guy', 'did', 'some', 'bitching', 'but', 'i', 'acted', 'like', 'i', 'be', 'interested', 'in', 'buying', 'something', 'else', 'next', 'week', 'and', 'he', 'gave', 'it', 'to', 'us', 'for', 'free']
# ['guy', 'bitching', 'acted', 'like', 'interested', 'buying', 'something', 'else', 'next', 'week', 'gave', 'us', 'free']
# ['rofl', '.', 'its', 'true', 'to', 'its', 'name']
# ['rofl', 'its', 'true', 'to', 'its', 'name']
# ['rofl', 'true', 'name']
#    target                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
tfid = TfidfVectorizer(max_features = 500)

# %%
X = tfid.fit_transform(df['transformed_text']).toarray()
y = df['target'].values

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test , y_train, y_test = train_test_split(X,y,test_size = 0.20, random_state = 2)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel= "sigmoid", gamma  = 1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth = 5)
lrc = LogisticRegression(solver = 'liblinear', penalty = 'l1')
rfc = RandomForestClassifier(n_estimators = 50, random_state = 2 )
abc = AdaBoostClassifier(n_estimators = 50, random_state = 2)
bc = BaggingClassifier(n_estimators = 50, random_state = 2)
etc = ExtraTreesClassifier(n_estimators = 50, random_state = 2)
gbdt = GradientBoostingClassifier(n_estimators = 50, random_state = 2)    
xgb  = XGBClassifier(n_estimators = 50, random_state = 2)

# %%
clfs = {
    'SVC': svc,
    'KNN': knc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'Adaboost': abc,
    'Bgc': bc,
    'ETC': etc,
    'GBDT': gbdt,
    'xgb': xgb
    
}

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score
def train_classifier(clfs, X_train, y_train, X_test, y_test):
    clfs.fit(X_train,y_train)
    y_pred = clfs.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    return accuracy , precision

# %%
accuracy_scores = []
precision_scores = []
for name , clfs in clfs.items():
    current_accuracy, current_precision = train_classifier(clfs, X_train, y_train, X_test, y_test)
    print()
    print("For: ", name)
    print("Accuracy: ", current_accuracy)
    print("Precision: ", current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For:  SVC
# Accuracy:  0.9661508704061895
# Precision:  0.9327731092436975
#
# For:  KNN
# Accuracy:  0.9274661508704062
# Precision:  1.0
#
# For:  NB
# Accuracy:  0.9709864603481625
# Precision:  0.9655172413793104
#
# For:  DT
# Accuracy:  0.9361702127659575
# Precision:  0.9
#
# For:  LR
# Accuracy:  0.9632495164410058
# Precision:  0.9629629629629629
#
# For:  RF
# Accuracy:  0.971953578336557
# Precision:  0.943089430894309
#
# For:  Adaboost
# Accuracy:  0.9613152804642167
# Precision:  0.9375
#
# For:  Bgc
# Accuracy:  0.965183752417795
# Precision:  0.9180327868852459
#
# For:  ETC
# Accuracy:  0.9729206963249516
# Precision:  0.9296875
#
# For:  GBDT
# Accuracy:  0.9506769825918762
# Precision:  0.9393939393939394
#
# For:  xgb
# Accuracy:  0.9709864603481625
# Precision:  0.9576271186440678
